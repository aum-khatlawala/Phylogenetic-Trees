# %%
import pandas

# %%
distance_data = pandas.read_csv("./Ndistance.txt", index_col=0)
names = {"KX951416.1":"A", "NM_205222.3":"B", "M57671.1":"C", "NM_173926.2":"D", "NM_019129.3":"E", "U03610.1": "F", "NM_001109772.1":"G", "NM_001130093.2":"H", "BT006808.1":"I", "NM_001008996.2":"J"}
distance_data.rename(index=names, columns=names, inplace=True)
distance_data
# Out:
#           A         B         C         D         E         F         G  \
# A  0.000000  0.573975  0.683544  0.649910  0.639640  0.647706  0.655296
# B  0.573975  0.000000  0.583490  0.554307  0.541199  0.554307  0.546314
# C  0.683544  0.583490  0.000000  0.459402  0.449893  0.408297  0.434498
# D  0.649910  0.554307  0.459402  0.000000  0.384289  0.410788  0.278396
# E  0.639640  0.541199  0.449893  0.384289  0.000000  0.386076  0.363441
# F  0.647706  0.554307  0.408297  0.410788  0.386076  0.000000  0.382353
# G  0.655296  0.546314  0.434498  0.278396  0.363441  0.382353  0.000000
# H  0.621818  0.520295  0.457806  0.397590  0.409736  0.326180  0.355691
# I  0.697248  0.602996  0.462585  0.409800  0.419006  0.364896  0.367347
# J  0.678636  0.569288  0.429194  0.316258  0.346237  0.394958  0.292517
#
#           H         I         J
# A  0.621818  0.697248  0.678636
# B  0.520295  0.602996  0.569288
# C  0.457806  0.462585  0.429194
# D  0.397590  0.409800  0.316258
# E  0.409736  0.419006  0.346237
# F  0.326180  0.364896  0.394958
# G  0.355691  0.367347  0.292517
# H  0.000000  0.377970  0.390244
# I  0.377970  0.000000  0.213942
# J  0.390244  0.213942  0.000000

# %%
half_list = []
labels = ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J']
distance_data = distance_data.to_numpy()
for i in range(0, 10, 1):
    temp = []
    for j in range(i):
        temp.append(distance_data[i][j])
    half_list.append(temp)
print(half_list)
# Out:
# [[], [0.5739750445632799], [0.6835443037974683, 0.5834896810506567], [0.6499102333931778, 0.5543071161048689, 0.4594017094017094], [0.6396396396396397, 0.5411985018726592, 0.4498933901918976, 0.3842887473460722], [0.6477064220183486, 0.5543071161048689, 0.408296943231441, 0.4107883817427386, 0.3860759493670886], [0.6552962298025135, 0.5463137996219282, 0.4344978165938865, 0.2783964365256124, 0.3634408602150538, 0.3823529411764705], [0.6218181818181818, 0.5202952029520295, 0.4578059071729958, 0.3975903614457831, 0.40973630831643, 0.3261802575107296, 0.3556910569105691], [0.6972477064220184, 0.602996254681648, 0.4625850340136054, 0.4097995545657015, 0.4190064794816415, 0.3648960739030023, 0.3673469387755102, 0.3779697624190065], [0.6786355475763016, 0.5692883895131086, 0.429193899782135, 0.3162583518930957, 0.3462365591397849, 0.3949579831932773, 0.2925170068027211, 0.3902439024390244, 0.2139423076923076]]

# %%
def UPGMA(table, labels):
    while len(labels) >= 2:
        # first, we find the minimum value in the table
        minimum = float(100)
        x, y = -1, -1
        for i in range(len(table)):
            for j in range(len(table[i])):
                if table[i][j] < minimum:
                    x, y = i, j
                    minimum = table[i][j]
        print (minimum)
        # then, we join the rows of the two indices which
        # contain the minimum value as per the UPGMA algorithm
        print(labels[x] + " and " + labels[y] + ": common ancestor at " + str(minimum/2) + " from the leaf node base of the tree")
        if y < x:
            x, y = y, x
        # we keep variables xcount and ycount to see what the weight of x and y is
        xcount=0
        ycount=0
        for i in labels[x]:
            # because we need to disregard the brackets
            if(i.isalpha()):
                xcount=xcount+1
        for i in labels[y]:
            # because we need to disregard the brackets
            if(i.isalpha()):
                ycount=ycount+1
        row = []
        # following the procedure shown in the tutorial to calculate
        # weighted average in every iteration
        for i in range(0, x):
            row.append((xcount*table[x][i] + ycount*table[y][i])/(xcount+ycount))
        table[x] = row
        for i in range(x+1, y):
            table[i][x] = (xcount*table[i][x]+ycount*table[y][i])/(xcount+ycount)
        for i in range(y+1, len(table)):
            table[i][x] = (xcount*table[i][x]+ycount*table[i][y])/(xcount+ycount)
            del table[i][y]
        del table[y]
        # finally, we join those two indices into the smaller index
        # and delete the larger valued index
        # absorption of the two entries with greatest similarity
        if y < x:
            x, y = y, x
        labels[x] = "(" + labels[x] + "," + labels[y] + ")"
        del labels[y]
        #print(labels)
        #print(xcount)
        #print(ycount)
        #print(table)
        #print("\n")
    return labels[0]

# %%
print("\nFinal relationship:\n" + UPGMA(half_list, labels))
print("where: ")
print(names)
# Out:
# 0.2139423076923076
# J and I: common ancestor at 0.1069711538461538 from the leaf node base of the tree
# 0.2783964365256124
# G and D: common ancestor at 0.1391982182628062 from the leaf node base of the tree
# 0.3261802575107296
# H and F: common ancestor at 0.1630901287553648 from the leaf node base of the tree
# 0.34648046300925717
# (I,J) and (D,G): common ancestor at 0.17324023150462858 from the leaf node base of the tree
# 0.3782431615456381
# E and ((D,G),(I,J)): common ancestor at 0.18912158077281904 from the leaf node base of the tree
# 0.38703027209133906
# (F,H) and (((D,G),(I,J)),E): common ancestor at 0.19351513604566953 from the leaf node base of the tree
# 0.4430963857696673
# ((((D,G),(I,J)),E),(F,H)) and C: common ancestor at 0.22154819288483366 from the leaf node base of the tree
# 0.5590245077377209
# (C,((((D,G),(I,J)),E),(F,H))) and B: common ancestor at 0.27951225386886047 from the leaf node base of the tree
# 0.6497525898923255
# (B,(C,((((D,G),(I,J)),E),(F,H)))) and A: common ancestor at 0.32487629494616277 from the leaf node base of the tree
#
# Final relationship:
# (A,(B,(C,((((D,G),(I,J)),E),(F,H)))))
# where:
# {'KX951416.1': 'A', 'NM_205222.3': 'B', 'M57671.1': 'C', 'NM_173926.2': 'D', 'NM_019129.3': 'E', 'U03610.1': 'F', 'NM_001109772.1': 'G', 'NM_001130093.2': 'H', 'BT006808.1': 'I', 'NM_001008996.2': 'J'}

# %%
(KX951416.1,(NM_205222.3,(M57671.1,((((NM_173926.2,NM_001109772.1),(BT006808.1,NM_001008996.2)),NM_019129.3),(U03610.1,NM_001130093.2)))))
